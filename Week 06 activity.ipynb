# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
filename='C:/Users/HP/Downloads/Dataset_w6.xlsx'
df=pd.read_excel(filename)
df
# Out:
#                                 country             Region  \
# 0                           Afghanistan       SouthernAsia
# 1                               Albania     SouthernEurope
# 2                               Algeria     NorthernAfrica
# 3                                Angola       MiddleAfrica
# 4                   Antigua and Barbuda          Caribbean
# ..                                  ...                ...
# 191  Venezuela (Bolivarian Republic of)       SouthAmerica
# 192                            Viet Nam  South-easternAsia
# 193                               Yemen        WesternAsia
# 194                              Zambia      EasternAfrica
# 195                            Zimbabwe      EasternAfrica
#
#      Surface area (km2)  Population in thousands (2017)  \
# 0                652864                           35530
# 1                 28748                            2930
# 2               2381741                           41318
# ...

# %% [markdown]
# 1. Find out how many countries are there in the dataset.

# %%
df.nunique()
# Out:
# country                                       196
# Region                                         22
# Surface area (km2)                            196
# Population in thousands (2017)                192
# GDP per capita (current US$)                  195
# Agricultural production index                  82
# International trade: Imports (million US$)    195
# dtype: int64

# %%
df['country'].nunique()# Num of countries
# Out:
# 196

# %% [markdown]
# Examine the data by using visualizations.

# %%
df_whole1=df.sort_values(by=["GDP per capita (current US$)","country"],ascending=False).head(196)

# %%
plt.figure(figsize = (20,10))
plt.title('GDP per capita in Regions',fontsize=25)
plt.xticks(rotation=90)
graph_whole1=sns.lineplot(df_whole1['Region'],df_whole1['GDP per capita (current US$)']);
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.corr()
# Out:
#                                             Surface area (km2)  \
# Surface area (km2)                                    1.000000
# Population in thousands (2017)                        0.448362
# GDP per capita (current US$)                          0.064154
# Agricultural production index                         0.086247
# International trade: Imports (million US$)            0.482636
#
#                                             Population in thousands (2017)  \
# Surface area (km2)                                                0.448362
# Population in thousands (2017)                                    1.000000
# GDP per capita (current US$)                                     -0.051922
# Agricultural production index                                     0.121782
# International trade: Imports (million US$)                        0.532012
#
#                                             GDP per capita (current US$)  \
# ...

# %%
sns.heatmap(df.corr(), cmap='coolwarm')
plt.show()

# %% [markdown]
#  Find out how many countries with respect to the region are available in the dataset

# %%
country=df.groupby("Region")["country"].count().sort_values()
country
# Out:
# Region
# Oceania               2
# NorthernAmerica       4
# Micronesia            4
# SouthernAfrica        5
# CentralAsia           5
# Polynesia             5
# NorthernAfrica        5
# Melanesia             5
# WesternEurope         7
# EasternAsia           7
# CentralAmerica        8
# SouthernAsia          9
# MiddleAfrica          9
# EasternEurope        10
# NorthernEurope       10
# South-easternAsia    11
# SouthAmerica         12
# SouthernEurope       12
# WesternAfrica        15
# Caribbean            16
# EasternAfrica        17
# WesternAsia          18
# Name: country, dtype: int64

# %% [markdown]
# On average which region has the highest
# a. GDP per capita (current US$)
# b. International trade: Imports (million US$)

# %%
gdp_high= df.groupby('Region')['GDP per capita (current US$)'].mean().round(2).sort_values()
gdp_high
# Out:
# Region
# WesternAfrica         1013.14
# EasternAfrica         2088.85
# SouthernAsia          2968.40
# MiddleAfrica          3928.83
# NorthernAfrica        3934.96
# SouthernAfrica        4191.90
# CentralAsia           4329.88
# Micronesia            5008.30
# CentralAmerica        6348.14
# SouthAmerica          8499.78
# Polynesia             8686.52
# Melanesia             9261.96
# EasternEurope         9292.49
# South-easternAsia    10299.03
# SouthernEurope       14462.74
# Caribbean            15135.56
# WesternAsia          17013.94
# EasternAsia          27967.61
# NorthernEurope       42098.22
# Oceania              44823.25
# WesternEurope        55387.13
# NorthernAmerica      57659.00
# Name: GDP per capita (current US$), dtype: float64

# %% [markdown]
# GDP per capita (current US$)On average which region has the highest
# NorthernAmerica      57659.00

# %%
Int_trade= df.groupby('Region')['International trade: Imports (million US$)'].mean().round(2).sort_values()
Int_trade
# Out:
# Region
# Micronesia               99.00
# Polynesia               432.00
# Melanesia              2896.40
# Caribbean              3057.31
# MiddleAfrica           4381.22
# EasternAfrica          4726.18
# WesternAfrica          4898.33
# CentralAsia           12063.40
# SouthernAfrica        18005.60
# SouthAmerica          32885.67
# NorthernAfrica        35034.40
# WesternAsia           46025.56
# CentralAmerica        57031.50
# SouthernAsia          58199.33
# SouthernEurope        76666.67
# EasternEurope         85243.90
# South-easternAsia     98324.64
# Oceania              112914.50
# NorthernEurope       113407.20
# WesternEurope        407498.43
# EasternAsia          451995.00
# NorthernAmerica      663552.25
# Name: International trade: Imports (million US$), dtype: float64

# %% [markdown]
# International trade: Imports (million US$ On average which region has the highest
# NorthernAmerica      663552.25

# %%
Consistent = df.groupby('Region')['GDP per capita (current US$)'].std ().round(2).sort_values()
Consistent
# Out:
# Region
# WesternAfrica          815.10
# NorthernAfrica         974.71
# SouthernAfrica        2177.55
# SouthernAsia          2855.71
# EasternAfrica         3716.13
# CentralAsia           4152.22
# CentralAmerica        4180.44
# SouthAmerica          4273.71
# Micronesia            4820.67
# MiddleAfrica          5274.85
# EasternEurope         5415.49
# Polynesia             6956.25
# Oceania               9233.33
# SouthernEurope        9541.70
# Melanesia            13855.84
# Caribbean            14579.37
# South-easternAsia    16311.81
# WesternAsia          18812.15
# NorthernEurope       20671.03
# WesternEurope        24770.47
# NorthernAmerica      25749.62
# EasternAsia          27485.12
# Name: GDP per capita (current US$), dtype: float64

# %%
Find out which region has more consistent with respect to GDP per
capita (current US$)=WesternAfrica          815.10
